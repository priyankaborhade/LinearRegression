# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
area = np.random.randint(500, 900, 40)
price = np.random.randint(30, 99, 40)

# %%
area
# Out:
# array([632, 830, 814, 673, 533, 696, 807, 567, 842, 634, 728, 887, 639,
#        723, 721, 690, 609, 808, 656, 899, 551, 652, 845, 555, 861, 737,
#        605, 523, 719, 891, 682, 684, 747, 718, 733, 632, 851, 890, 711,
#        688])

# %%
price
# Out:
# array([31, 96, 71, 69, 42, 51, 85, 70, 94, 40, 46, 39, 76, 92, 58, 67, 31,
#        54, 45, 48, 78, 84, 91, 85, 79, 71, 77, 36, 93, 46, 53, 40, 67, 34,
#        86, 54, 41, 61, 73, 72])

# %%
area.sort()
price.sort()

# %%
area
# Out:
# array([523, 533, 551, 555, 567, 605, 609, 632, 632, 634, 639, 652, 656,
#        673, 682, 684, 688, 690, 696, 711, 718, 719, 721, 723, 728, 733,
#        737, 747, 807, 808, 814, 830, 842, 845, 851, 861, 887, 890, 891,
#        899])

# %%
price
# Out:
# array([31, 31, 34, 36, 39, 40, 40, 41, 42, 45, 46, 46, 48, 51, 53, 54, 54,
#        58, 61, 67, 67, 69, 70, 71, 71, 72, 73, 76, 77, 78, 79, 84, 85, 85,
#        86, 91, 92, 93, 94, 96])

# %%
# %matplotlib inline
plt.title("Area vs Price")
plt.xlabel("Area in SqFt")
plt.ylabel("Price in Lakh")
plt.scatter(area, price, marker="*", c="r")
plt.show()
plt.savefig("linear data example.png")

# %%
# %matplotlib inline
plt.title("Area vs Price")
plt.xlabel("Area in SqFt")
plt.ylabel("Price in Lakh")
plt.plot(area, price, 'b-*')
plt.show()
plt.savefig("linear data example.jpg")

# %%
data = {"Area":area, "Price":price}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Area  Price
# 0    523     31
# 1    533     31
# 2    551     34
# 3    555     36
# 4    567     39
# 5    605     40
# 6    609     40
# 7    632     41
# 8    632     42
# 9    634     45
# 10   639     46
# 11   652     46
# 12   656     48
# 13   673     51
# 14   682     53
# 15   684     54
# 16   688     54
# 17   690     58
# 18   696     61
# 19   711     67
# 20   718     67
# 21   719     69
# 22   721     70
# 23   723     71
# 24   728     71
# 25   733     72
# 26   737     73
# 27   747     76
# 28   807     77
# 29   808     78
# 30   814     79
# 31   830     84
# 32   842     85
# 33   845     85
# 34   851     86
# 35   861     91
# 36   887     92
# 37   890     93
# 38   891     94
# 39   899     96

# %%
X = df.drop("Price", axis = 1)
y = df["Price"]

# %%
X.head(3)
# Out:
#    Area
# 0   523
# 1   533
# 2   551

# %%
y.head(3)
# Out:
# 0    31
# 1    31
# 2    34
# Name: Price, dtype: int32

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.predict([[650]])
# Out:
# array([50.97941044])

# %%
model.predict([[1200]])
# Out:
# array([151.52502454])

# %%
y_pred = model.predict(X)

# %%
# %matplotlib inline
plt.title("Area vs Price")
plt.xlabel("Area in SqFt")
plt.ylabel("Price in Lakh")
plt.scatter(area, price, marker="*", c="g")
plt.plot(area, price, 'r--')
plt.plot(area, y_pred, 'b-')
plt.legend(["Actual Points", "Actual Line", "Best Fit Line"])
plt.show()

# %%
coef = model.coef_
intercept = model.intercept_

# %%
print("Coefficient of x is",coef)
print("Intercept of y is",intercept)
# Out:
# Coefficient of x is [0.18281021]
# Intercept of y is -67.84722441410815
